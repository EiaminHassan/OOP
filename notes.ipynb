# %% [markdown]
# **OOP stands for Object-Oriented Programming.**
#
# Python is an object-oriented language, allowing you to structure your code using classes and objects for better organization and reusability.

# %% [markdown]
# **Advantages of OOP**
# 1. Provides a clear structure to programs
# 2. Makes code easier to maintain, reuse, and debug
# 3. Follows DRY (Don't Repeat Yourself) principle, reducing code duplication
#
# - DRY: The DRY principle means you should avoid writing the same code more than once. Move repeated code into functions or classes and reuse it.

# %% [markdown]
# **Classes & Objects**
# - A class is a blueprint for creating objects. It defines a set of attributes and methods that the created objects will have.
# - An object is an instance of a class.
# - Example:
# Fruit is a class and apple is an object of Fruit class.
#
# - When you create an object from a class, it inherits all the variables and functions defined inside that class.

# %% [markdown]
# **The \__init__() method:**
# - All classes have a built-in method called \__init__(), which is always executed when the class is being initiated.
#
# - The \__init__() method is used to assign values to object properties, or to perform operations that are necessary when the object is being created.

# %% [markdown]
# **Python self parameter**
# - The self parameter is a reference to the current instance of the class. It is used to access properties and methods that belong to the class.

# %% [markdown]
# **Class Properties**
# - Properties are variables that belong to a class. They store data for each object created from the class.
# - You can access object properties using dot notation
